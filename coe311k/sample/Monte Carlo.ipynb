# %%
import random
def approximatePi(numSamples):
    x, y, counter = 0, 0, 0
    for s in range(0, numSamples):
        x, y = random.uniform(-1, 1), random.uniform(-1,1)
        if (x**2 + y**2)<=1:
            counter += 1
    pi = 4* counter/numSamples
    return pi
print(approximatePi(10000000))
# Out:
# 3.1415588
