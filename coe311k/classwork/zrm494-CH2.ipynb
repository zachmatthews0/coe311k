# %%
num = 2025
binary = []
while num>0:
    if num % 2 == 0:
        binary.insert(0, 0)
    else:
        binary.insert(0, 1)
    num = int(num/2)
for i in binary:
    print(i, end = "")
# Out:
# 11111101001
