# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 20)

plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x), 'r')
plt.subplot(2, 2, 2)
plt.scatter(x, np.cos(x))
plt.subplot(2, 2, 3)
plt.bar(x, x**2)
plt.subplot(2, 2, 4)
plt.step(x, np.sqrt(x))
