# %%
import numpy as np
import random
import matplotlib.pyplot as plt

#start with random y = mx + c
real_m = random.randint(1, 5)
real_c = random.randint(1, 5)

x = np.linspace(0, 1, 101)
y = np.zeros(len(x))
for i in range(0, len(x)):
    y[i] = real_m * x[i] + real_c + np.random.uniform(-1, 1)

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([x, np.ones(len(x))]).T

# Solve using least squares/Polyfit
m, c = np.linalg.lstsq(A, y, rcond=None)[0]
coefficients = np.polyfit(x, y, 3)
print(coefficients)
print(f"Real Slope: {real_m}, Real Intercept: {real_c}")
print(f"Lstsq Slope: {m}, Lstsq Intercept: {c}")
xlin = np.linspace(0, 1, 101)
ypoly = (coefficients[0] + coefficients[1]*(xlin) + coefficients[2]*(xlin**2) +coefficients[3]*(xlin**3))

#plt.plot(xlin, xlin*m + c, 'r-')
plt.plot(xlin, ypoly, 'r-')
plt.scatter(x, y)
plt.show()
Resid = np.abs(y - (xlin*m + c))
print('Residuals:')
print(Resid)
print('Max Resid:', np.max(Resid), '@', np.argmax(Resid)/100.0)
print('Min Resid:', np.min(Resid), '@', np.argmin(Resid)/100.0)
# Out:
# [ 0.56911817 -0.72890778  2.62316782  3.24639465]
# Real Slope: 3, Real Intercept: 3
# Lstsq Slope: 2.408162370377361, Lstsq Intercept: 3.2534156101873797
# Residuals:
# [0.62762783 0.69749123 0.60287033 0.27774381 0.99681141 0.94605022
#  0.47019942 0.47342902 0.21317099 0.53033608 0.72115445 0.70815632
#  0.02808115 0.79277431 0.08025602 0.0402555  0.49955589 0.60608612
#  1.0135972  0.56188897 0.31610952 0.11133401 0.44694019 0.33877472
#  0.06205166 0.36633334 0.28887798 0.89746771 0.74965406 0.13493727
#  0.73253302 0.52805364 0.77920786 0.45525967 0.816985   0.29039356
#  0.00910105 0.32660161 0.60937859 0.34855068 0.85813908 0.64249052
#  0.2206355  0.95775853 0.8626715  0.47902524 0.17095114 0.93121824
#  0.3449072  0.15860955 0.79427354 0.0360048  0.11415017 0.91099371
#  0.41804643 0.11040029 0.83668658 0.78516661 0.67423093 0.65401284
#  0.216841   0.55868965 0.27511163 0.27271628 0.41160727 0.45843667
#  0.21107354 0.80749038 0.58040767 0.13944444 0.16022338 0.23489882
#  0.49942015 0.70596731 1.04172616 0.37447987 0.40258639 0.31469698
#  0.35792575 0.44714186 0.53803702 0.64506769 0.1374157  0.41802317
#  0.03609115 0.48573227 0.09258074 1.11677911 1.10579717 0.16478186
#  0.71107016 0.35378376 0.31442473 0.12875022 0.27840179 0.63942825
#  0.03292525 0.43942213 0.91707243 0.10368585 0.28419689]
# Max Resid: 1.1167791083203937 @ 0.87
# Min Resid: 0.009101054522123064 @ 0.36
