# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
xlin = np.linspace(0, 5, 6)

plt.plot(xlin, xlin*m + c, 'r-')
plt.scatter(X, Y)
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
# Data points
X = np.zeros(np.random.randint(10,20))
for i in range(0, len(X)):
    X[i] = np.random.uniform(0,50)
X = np.sort(X)
print(X)

Y = np.zeros(len(X))
for i in range(0, len(Y)):
    Y[i] = np.random.uniform(0,50)
print(Y)

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
xlin = np.linspace(0, 50, 51)

plt.plot(xlin, xlin*m + c, 'r-')
plt.scatter(X, Y)
# Out:
# [ 1.45283507  4.78397665  5.28776273  8.48966812  9.19410811 10.82498442
#  14.69103631 16.0141145  18.0197193  30.05988283 32.08953075 35.07664856
#  35.1870912  40.98365983 41.33330709 47.09725671 48.90785779]
# [ 8.55594756 42.08899014 43.25321968 23.11923987 47.14586276 11.09346654
#  47.2962396  24.34999638 48.53537071 43.43873611  9.23148887 45.88397834
#  47.72315334 14.77119746 41.10008561 43.46335454 10.44240396]
# Slope: -0.013439458123113273, Intercept: 32.756570989345555

# %%
#start with random y = mx + c
real_m = random.randint(1, 5)
real_c = random.randint(1, 5)

x = np.linspace(0, 1, 101)
y = np.zeros(len(x))
for i in range(0, len(x)):
    y[i] = real_m * x[i] + real_c + np.random.uniform(-1, 1)

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([x, np.ones(len(x))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, y, rcond=None)[0]
print(f"Real Slope: {real_m}, Real Intercept: {real_c}")
print(f"Lstsq Slope: {m}, Lstsq Intercept: {c}")
xlin = np.linspace(0, 1, 101)

plt.plot(xlin, xlin*m + c, 'r-')
plt.scatter(x, y)

Resid = np.abs(y - (xlin*m + c))
print('Residuals:')
print(Resid)
print('Max Resid:', np.max(Resid), '@', np.argmax(Resid)/100.0)
print('Min Resid:', np.min(Resid), '@', np.argmin(Resid)/100.0)
# Out:
# Real Slope: 5, Real Intercept: 3
# Lstsq Slope: 4.978297379710922, Lstsq Intercept: 3.0015704959977345
# Residuals:
# [0.93218852 0.11143329 0.10907088 0.88228387 0.89553768 0.43424918
#  0.51753295 0.38657497 0.85335333 0.61129916 0.37814595 0.41610369
#  0.1789063  0.85372698 0.80831931 0.61369566 0.52499279 0.84771317
#  0.92625222 0.3187974  0.36353068 0.59572213 0.65545819 0.60156264
#  0.61656739 0.46834    0.19058537 0.18080473 0.57678457 0.4722722
#  0.94039971 0.31667193 0.21434835 0.04075896 0.28616289 0.93263159
#  0.47262217 0.96633953 0.84770538 0.11283848 0.48003429 0.90565424
#  0.59284114 0.92419014 0.64294376 0.77183847 0.97674692 0.36639579
#  0.68511699 0.76857876 0.33316638 0.22303627 0.60573624 0.91915553
#  0.05060071 0.6213454  0.21850173 0.12119403 0.31261863 0.13810009
#  0.22963234 0.42725351 0.67878452 0.18019864 0.49190387 0.30556296
#  0.26570665 0.68275612 0.60030671 0.16080287 0.01126549 0.65072528
#  0.14737745 0.67175883 0.10082515 0.46620381 0.51458012 0.69027545
#  1.01189962 0.62065402 0.50784005 0.8452856  0.44036878 0.5018093
#  0.64003993 0.60240705 0.16960912 0.858554   0.95129243 0.32961186
#  0.52049118 0.36380222 0.3062018  0.78724962 0.10272821 0.88279957
#  0.90645546 0.45008551 0.53686524 0.65426373 0.7400876 ]
# Max Resid: 1.0118996196491077 @ 0.78
# Min Resid: 0.011265492733631532 @ 0.7
