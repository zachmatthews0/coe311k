# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# Data points
X = np.zeros(np.random.randint(10,20))
for i in range(0, len(X)):
    X[i] = np.random.uniform(0,50)
X = np.sort(X)
print(X)

Y = np.zeros(len(X))
for i in range(0, len(Y)):
    Y[i] = np.random.uniform(0,50)
print(Y)

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
xlin = np.linspace(0, 50, 51)

plt.plot(xlin, xlin*m + c, 'r-')
plt.scatter(X, Y)
# Out:
# [ 2.39229646  4.57063368  4.86744209 13.93138132 18.35266691 28.41751603
#  31.23669979 42.05020254 43.52770664 46.06074745 48.07493633]
# [39.99474021 39.28361508 42.03410362 22.69327375  4.53149552  1.39135746
#  45.92106466 10.08998922 31.9341306  40.21434803 34.60089458]
# Slope: -0.1189390541694599, Intercept: 31.491465542362967
