# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

 

# Define known data points

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

# Create a cubic spline interpolation of the data

cs = CubicSpline(x, y, bc_type='natural')# Generate new x values for a smooth plot

x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

coefficients = np.polyfit(x, y, 3)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(x_interp)

coefficients5 = np.polyfit(x, y, 5)
polynomial5 = np.poly1d(coefficients5)
y_pred5 = polynomial5(x_interp)

plt.plot(x_interp, y_interp, 'r-') #splines
plt.plot(x_interp, y_pred, 'b-') #3 degrees
plt.plot(x_interp, y_pred5, 'g-') #3 degrees
plt.scatter(x, y)

# %% [markdown]
# Splines do a really good job at hitting all the points (unlike a low degree polyfit) without adding weird overshoots like an overfitted polynomial would.
